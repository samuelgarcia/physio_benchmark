# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from benchmark_r_peak import *
import seaborn as sns

# %%
perfs = benchmark_many_subject()

# %%
perfs
# Out:
#                          tp    fn   fp  accuracy  precision    recall
# subject_id case
# subject_00 hand_bike  176.0   0.0  0.0  1.000000        1.0  1.000000
#            jogging    253.0   0.0  0.0  1.000000        1.0  1.000000
#            maths      144.0   0.0  0.0  1.000000        1.0  1.000000
#            sitting    140.0   0.0  0.0  1.000000        1.0  1.000000
#            walking    165.0   0.0  0.0  1.000000        1.0  1.000000
# ...                     ...   ...  ...       ...        ...       ...
# subject_24 hand_bike  149.0   0.0  0.0  1.000000        1.0  1.000000
#            jogging    185.0  83.0  0.0  0.690299        1.0  0.690299
#            maths      140.0   0.0  0.0  1.000000        1.0  1.000000
#            sitting    135.0   0.0  0.0  1.000000        1.0  1.000000
#            walking    151.0   0.0  0.0  1.000000        1.0  1.000000
#
# [123 rows x 6 columns]

# %%
perfs2 = perfs.reset_index()
sns.catplot(perfs2, x='subject_id', y='accuracy', col='case', hue='case', kind='bar')
